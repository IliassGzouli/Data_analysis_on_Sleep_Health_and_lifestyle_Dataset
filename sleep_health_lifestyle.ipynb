# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
lifestyle=pd.read_csv("Sleep_health_and_lifestyle_dataset.csv")

# %%
lifestyle
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# 1                   6                       60             8       Normal
# 2                   6                       60             8       Normal
# 3                   4                       30             8        Obese
# 4                   4                       30             8        Obese
# ..                ...                      ...           ...          ...
# 369                 9                       75             3   Overweight
# 370                 9                       75             3   Overweight
# 371                 9                       75             3   Overweight
# 372                 9                       75             3   Overweight
# 373                 9                       75             3   Overweight
#
#     Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0           126/83          77         4200            NaN
# 1           125/80          75        10000            NaN
# 2           125/80          75        10000            NaN
# 3           140/90          85         3000    Sleep Apnea
# 4           140/90          85         3000    Sleep Apnea
# ..             ...         ...          ...            ...
# 369         140/95          68         7000    Sleep Apnea
# 370         140/95          68         7000    Sleep Apnea
# 371         140/95          68         7000    Sleep Apnea
# 372         140/95          68         7000    Sleep Apnea
# 373         140/95          68         7000    Sleep Apnea
#
# [374 rows x 13 columns]

# %%
lifestyle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           155 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
mean_sleep_duration=np.mean(lifestyle["Sleep Duration"].to_numpy())

# %%
sum_sleep_duration=np.sum(lifestyle["Sleep Duration"].to_numpy())

# %%
mean_sleep_duration
# Out:
# np.float64(7.132085561497325)

# %%
mean_age=np.mean(lifestyle["Age"].to_numpy())

# %%
mean_age
# Out:
# np.float64(42.18449197860963)

# %%
data=lifestyle.groupby("Age")["Gender"].value_counts()

# %%
data
# Out:
# Age  Gender
# 27   Male       1
# 28   Male       5
# 29   Male      11
#      Female     2
# 30   Male      11
#      Female     2
# 31   Male      17
#      Female     1
# 32   Male      17
# 33   Male      11
#      Female     2
# 34   Female     2
# 35   Male      11
#      Female     1
# 36   Female    10
#      Male       2
# 37   Female    15
#      Male       5
# 38   Male      11
#      Female     9
# 39   Male      12
#      Female     3
# 40   Female     2
#      Male       2
# 41   Male      12
# 42   Male       7
#      Female     2
# 43   Male      31
#      Female     3
# 44   Male      19
#      Female    11
# 45   Female    14
# 48   Male       2
#      Female     1
# 49   Female     9
#      Male       2
# 50   Female    20
# 51   Female     8
# 52   Female     9
# 53   Female    17
# 54   Female     7
# 55   Female     2
# 56   Female     2
# 57   Female     9
# 58   Female     6
# 59   Female    16
# Name: count, dtype: int64

# %%
hours_gender = lifestyle.groupby("Age")

# %%
hours_gender.count()
# Out:
#      Person ID  Gender  Occupation  Sleep Duration  Quality of Sleep  \
# Age
# 27           1       1           1               1                 1
# 28           5       5           5               5                 5
# 29          13      13          13              13                13
# 30          13      13          13              13                13
# 31          18      18          18              18                18
# 32          17      17          17              17                17
# 33          13      13          13              13                13
# 34           2       2           2               2                 2
# 35          12      12          12              12                12
# 36          12      12          12              12                12
# 37          20      20          20              20                20
# 38          20      20          20              20                20
# 39          15      15          15              15                15
# 40           4       4           4               4                 4
# 41          12      12          12              12                12
# 42           9       9           9               9                 9
# 43          34      34          34              34                34
# 44          30      30          30              30                30
# 45          14      14          14              14                14
# 48           3       3           3               3                 3
# 49          11      11          11              11                11
# 50          20      20          20              20                20
# 51           8       8           8               8                 8
# 52           9       9           9               9                 9
# 53          17      17          17              17                17
# 54           7       7           7               7                 7
# 55           2       2           2               2                 2
# 56           2       2           2               2                 2
# 57           9       9           9               9                 9
# 58           6       6           6               6                 6
# 59          16      16          16              16                16
#
#      Physical Activity Level  Stress Level  BMI Category  Blood Pressure  \
# Age
# 27                         1             1             1               1
# 28                         5             5             5               5
# 29                        13            13            13              13
# 30                        13            13            13              13
# 31                        18            18            18              18
# 32                        17            17            17              17
# 33                        13            13            13              13
# 34                         2             2             2               2
# 35                        12            12            12              12
# 36                        12            12            12              12
# 37                        20            20            20              20
# 38                        20            20            20              20
# 39                        15            15            15              15
# 40                         4             4             4               4
# 41                        12            12            12              12
# 42                         9             9             9               9
# 43                        34            34            34              34
# 44                        30            30            30              30
# 45                        14            14            14              14
# 48                         3             3             3               3
# 49                        11            11            11              11
# 50                        20            20            20              20
# 51                         8             8             8               8
# 52                         9             9             9               9
# 53                        17            17            17              17
# 54                         7             7             7               7
# 55                         2             2             2               2
# 56                         2             2             2               2
# 57                         9             9             9               9
# 58                         6             6             6               6
# 59                        16            16            16              16
#
#      Heart Rate  Daily Steps  Sleep Disorder
# Age
# 27            1            1               0
# 28            5            5               3
# 29           13           13               4
# 30           13           13               2
# 31           18           18               1
# 32           17           17               0
# 33           13           13               1
# 34            2            2               2
# 35           12           12               1
# 36           12           12               4
# 37           20           20               0
# 38           20           20               2
# 39           15           15               2
# 40            4            4               0
# 41           12           12               1
# 42            9            9               3
# 43           34           34              19
# 44           30           30              28
# 45           14           14              11
# 48            3            3               3
# 49           11           11              10
# 50           20           20              18
# 51            8            8               3
# 52            9            9               6
# 53           17           17               1
# 54            7            7               0
# 55            2            2               2
# 56            2            2               0
# 57            9            9               8
# 58            6            6               6
# 59           16           16              14

# %%
   
hours_gender=dict()
for age,group in hours_gender:
    hours_gender[age]=sum(group["Sleep Duration"])

# %%
hours_gender
# Out:
# {}

# %%
data1=lifestyle["Gender"].value_counts()

# %%
lifestyle.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder'],
#       dtype='object')

# %%
type(data1)
# Out:
# pandas.core.series.Series

# %%
x = lifestyle["Age"].tolist()
y = lifestyle["Stress Level"].tolist()
plt.rcParams["figure.figsize"]=[16,9]
plt.scatter(x,y, color='blue', marker="o", label='Points')
plt.xlabel("Age")
plt.ylabel("Stress Level")
plt.title("Stess level per age")
plt.show()
plt.grid=True

# %%
x = lifestyle["Age"].tolist()
y = lifestyle["Stress Level"].tolist()
plt.rcParams["figure.figsize"]=[16,9]
plt.plot(x,y, color='blue', marker="o", label='Points')
plt.xlabel("Age")
plt.ylabel("Stress Level")
plt.title("Stess level per age")
plt.show()

# %%
x = lifestyle["Age"].tolist()
y = lifestyle["Stress Level"].tolist()
plt.rcParams["figure.figsize"]=[16,9]
plt.bar(x,y, color='green')
plt.xlabel("Age")
plt.ylabel("Stress Level")
plt.title("Stess level per age")
plt.show()

# %%
plt.title("Stess level")
y = lifestyle["Stress Level"].tolist()
plt.rcParams["figure.figsize"]=[16,9]
plt.boxplot(y)
plt.ylabel("Stress Level")
plt.show()

# %%
stress_group=lifestyle.groupby("Stress Level").size()
x = stress_group.values
labels=stress_group.index
plt.rcParams["figure.figsize"]=[16,9]
plt.pie(x, labels=labels,autopct='%1.1f%%', shadow=True, startangle=90)
plt.title("The proportion of the different categories of “Stress Level”")
plt.show()

# %%
stress_group=lifestyle["Stress Level"]
age_group=lifestyle["Age"]
labels=stress_group.index
plt.rcParams["figure.figsize"]=[16,9]
plt.hist2d(stress_group,age_group, bins=[20,20],cmap="BuPu")
plt.colorbar(label="La valeur de stress ")
plt.xlabel("Age")
plt.ylabel("Stress Level")
plt.title("Stess level per age")
plt.show()

# %%
sns.boxenplot(x="Gender", y="Heart Rate", data=lifestyle, palette="pastel")
plt.title("Heart rate per gender")
# Out:
# /var/folders/r8/k96sg_qj0hl_sng_4mxjv1cw0000gn/T/ipykernel_5659/2702837793.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxenplot(x="Gender", y="Heart Rate", data=lifestyle, palette="pastel")
# Text(0.5, 1.0, 'Heart rate per gender')

# %%
bins = [0,20,30,40,50,60,70,80,100]
labels=["0-20","21-30","31-40","41-50","51-60","61-70","71-80","81+"]
lifestyle["Age groupe"]= pd.cut(lifestyle["Age"], bins=bins, labels=labels, right=False)
sns.boxenplot(x="Gender", y="Heart Rate", hue="Age groupe",data=lifestyle, palette="pastel")
plt.title("Heart rate per gender")
# Out:
# Text(0.5, 1.0, 'Heart rate per gender')

# %%
sns.pairplot(lifestyle, hue="Gender")

# %%
sns.pairplot(lifestyle)

# %%
sns.boxplot(data=lifestyle,x="Sleep Duration",y="Age", hue="Gender",palette="pastel")
plt.title("Sleep duration per age")
# Out:
# Text(0.5, 1.0, 'Sleep duration per age')

# %%
sns.displot(lifestyle["Daily Steps"])
plt.title("Daily steps")
# Out:
# Text(0.5, 1.0, 'Daily steps')

# %%
sns.jointplot(data=lifestyle,x="BMI Category", y="Age", palette="pastel")
plt.title("BMI category per age", pad=75)
# Out:
# Text(0.5, 1.0, 'BMI category per age')

# %%
plt.rcParams["figure.figsize"]=[16,9]
plt.title("Heart rate per age")
plt.scatter(x=lifestyle["Age"],y=lifestyle["Heart Rate"] ,cmap="seismic")
plt.xlabel("Age")
plt.ylabel("Heart Rate")
plt.show()
# Out:
# /var/folders/r8/k96sg_qj0hl_sng_4mxjv1cw0000gn/T/ipykernel_5659/1664175746.py:3: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x=lifestyle["Age"],y=lifestyle["Heart Rate"] ,cmap="seismic")

# %%
plt.rcParams["figure.figsize"]=[16,9]
plt.title("Heart rate per gender")
plt.xlabel("Gender")
plt.ylabel("Heart rate")
plt.bar(x=lifestyle["Gender"],height=lifestyle["Heart Rate"] )
plt.show()

# %%
plt.rcParams["figure.figsize"]=[9,9]
donnees=lifestyle['Gender'].value_counts()
plt.pie(donnees.values, labels=donnees.index, autopct='%1.1f%%',shadow=True, startangle=90)
plt.title("Gender percentage")
plt.show()

# %%
plt.rcParams["figure.figsize"]=[9,9]
lifestyle["Blood Pressure"].unique()
sns.boxplot(data=lifestyle, x="Blood Pressure", y="Age")
plt.xticks(rotation=45)
plt.title("Blood pressure per age")
plt.show()

# %%
plt.title("Heatmap")
cor=lifestyle[["Daily Steps", "Age","Stress Level","Heart Rate"]].corr()
sns.heatmap(cor, annot=True, cmap="seismic")
plt.show()

# %%
sns.kdeplot(data=lifestyle, x="Quality of Sleep", hue="Age", fill=True)
plt.title("Quality of sleep per age")
plt.show()
# Out:
# /var/folders/r8/k96sg_qj0hl_sng_4mxjv1cw0000gn/T/ipykernel_5659/3016595488.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(data=lifestyle, x="Quality of Sleep", hue="Age", fill=True)

# %%
sns.kdeplot(data=lifestyle, x="Physical Activity Level", hue="Gender", fill=True)
plt.title("Physical activity level per gender")
plt.show()

# %%
sns.histplot(data=lifestyle, x="Quality of Sleep", hue="Gender", kde=True)
plt.title("Quality of sleep per gender")
plt.show()

# %%
sns.lineplot(data=lifestyle, x="Sleep Duration", y="Physical Activity Level", hue="Gender")
plt.title("Sleep duration per physical activity level")
plt.show()

# %%
plt.title("Daily steps per gender")
plt.ylabel("Frequency")
sns.histplot(data=lifestyle, x="Daily Steps", hue="Gender", kde=True)
plt.show()

# %%
sns.scatterplot(data=lifestyle, x="Age", y="Daily Steps", hue="Gender")
sns.lineplot(data=lifestyle, x="Age", y="Daily Steps", hue="Gender", markers=False)
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05,1), loc=2)
plt.title("Daily steps per age and gender")
plt.show()

# %%
sns.scatterplot(data=lifestyle, x="Age", y="Sleep Disorder", hue="Gender")
sns.lineplot(data=lifestyle, x="Age", y="Sleep Disorder", hue="Gender", markers=False)
plt.xticks(rotation=45)
plt.legend(bbox_to_anchor=(1.05,1), loc=2)
plt.title("Sleep disorder per age and gender")
plt.show()

# %%
sns.barplot(data=lifestyle, x="Age", y="Physical Activity Level")
plt.title("Physical activity level per age")
plt.show()

# %%
sns.barplot(data=lifestyle, x="Occupation", y="Stress Level", ci=None, palette="muted")
plt.xticks(rotation=80)
plt.title("Stress level per occupation")
plt.show()
# Out:
# /var/folders/r8/k96sg_qj0hl_sng_4mxjv1cw0000gn/T/ipykernel_5659/2899299763.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(data=lifestyle, x="Occupation", y="Stress Level", ci=None, palette="muted")
# /var/folders/r8/k96sg_qj0hl_sng_4mxjv1cw0000gn/T/ipykernel_5659/2899299763.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=lifestyle, x="Occupation", y="Stress Level", ci=None, palette="muted")
